# %%
#load pandas
import pandas as pd

#load data
household_income = pd.read_csv("https://data.wprdc.org/datastore/dump/b119be7e-1c70-4bbe-bf34-2056fef533ec?inner_span=True")

# %%
household_income.head(10)
# Out:
#         Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0   Allegheny Center   1             870.0                93.000000
# 1     Allegheny West   2             146.0                36.000000
# 2          Allentown   3            1069.0               132.457540
# 3          Arlington   4             701.0               104.465305
# 4  Arlington Heights   5             144.0                59.000000
# 5         Banksville   6            1946.0               229.222599
# 6  Bedford Dwellings   7             723.0                53.000000
# 7          Beechview   8            3567.0               258.027130
# 8        Beltzhoover   9             848.0               156.057682
# 9         Bloomfield  10            4571.0               205.494525
#
#    Estimate; Total: - Less than $10,000  \
# 0                                 147.0
# 1                                   0.0
# 2                                 190.0
# 3                                  70.0
# 4                                  48.0
# 5                                  51.0
# 6                                 307.0
# 7                                 269.0
# 8                                 132.0
# 9                                 521.0
#
#    Margin of Error; Total: - Less than $10,000  \
# 0                                    57.000000
# 1                                    10.000000
# 2                                    82.134037
# 3                                    42.497059
# 4                                    42.000000
# 5                                    43.588989
# 6                                    75.000000
# 7                                   102.547550
# 8                                    88.147603
# 9                                   117.940663
#
#    Estimate; Total: - $10,000 to $14,999  \
# 0                                  115.0
# 1                                    3.0
# 2                                   78.0
# 3                                   35.0
# 4                                   23.0
# 5                                   72.0
# 6                                  129.0
# 7                                  136.0
# 8                                  182.0
# 9                                  261.0
#
#    Margin of Error; Total: - $10,000 to $14,999  \
# 0                                     54.000000
# 1                                      7.000000
# 2                                     42.825226
# 3                                     26.870058
# 4                                     27.000000
# 5                                     75.822160
# 6                                     50.000000
# 7                                     64.822835
# 8                                     95.519631
# 9                                     69.907081
#
#    Estimate; Total: - $15,000 to $19,999  \
# 0                                   30.0
# 1                                    4.0
# 2                                   78.0
# 3                                   56.0
# 4                                   43.0
# 5                                  155.0
# 6                                   91.0
# 7                                  244.0
# 8                                   63.0
# 9                                  297.0
#
#    Margin of Error; Total: - $15,000 to $19,999  ...  \
# 0                                     21.000000  ...
# 1                                      6.000000  ...
# 2                                     80.305666  ...
# 3                                     29.086079  ...
# 4                                     52.000000  ...
# 5                                     83.048179  ...
# 6                                     48.000000  ...
# 7                                    100.064979  ...
# 8                                     44.440972  ...
# 9                                     81.111035  ...
#
#    Estimate; Total: - $75,000 to $99,999  \
# 0                                   73.0
# 1                                   11.0
# 2                                   36.0
# 3                                  141.0
# 4                                    0.0
# 5                                  251.0
# 6                                    0.0
# 7                                  427.0
# 8                                   43.0
# 9                                  519.0
#
#    Margin of Error; Total: - $75,000 to $99,999  \
# 0                                     39.000000
# 1                                     10.000000
# 2                                     32.015621
# 3                                     54.212545
# 4                                     10.000000
# 5                                    108.189648
# 6                                     10.000000
# 7                                    114.017543
# 8                                     36.945906
# 9                                    103.754518
#
#    Estimate; Total: - $100,000 to $124,999  \
# 0                                     26.0
# 1                                     20.0
# 2                                     31.0
# 3                                     23.0
# 4                                      0.0
# 5                                    126.0
# 6                                      0.0
# 7                                    279.0
# 8                                      7.0
# 9                                    168.0
#
#    Margin of Error; Total: - $100,000 to $124,999  \
# 0                                       18.000000
# 1                                       17.000000
# 2                                       42.941821
# 3                                       17.804494
# 4                                       10.000000
# 5                                       71.337227
# 6                                       10.000000
# 7                                      102.990291
# 8                                       20.518285
# 9                                       55.488738
#
#    Estimate; Total: - $125,000 to $149,999  \
# 0                                     25.0
# 1                                      0.0
# 2                                     14.0
# 3                                      6.0
# 4                                      0.0
# 5                                    156.0
# 6                                      0.0
# 7                                     87.0
# 8                                      0.0
# 9                                    155.0
#
#    Margin of Error; Total: - $125,000 to $149,999  \
# 0                                       25.000000
# 1                                       10.000000
# 2                                       27.856777
# 3                                       16.248077
# 4                                       10.000000
# 5                                       91.285267
# 6                                       10.000000
# 7                                       50.189640
# 8                                       20.000000
# 9                                       63.898357
#
#    Estimate; Total: - $150,000 to $199,999  \
# 0                                     12.0
# 1                                      9.0
# 2                                      0.0
# 3                                      7.0
# 4                                      0.0
# 5                                     64.0
# 6                                      0.0
# 7                                     45.0
# 8                                     15.0
# 9                                    125.0
#
#    Margin of Error; Total: - $150,000 to $199,999  \
# 0                                       17.000000
# 1                                       13.000000
# 2                                       17.320508
# 3                                       17.320508
# 4                                       10.000000
# 5                                       45.442271
# 6                                       10.000000
# 7                                       40.583248
# 8                                       23.194827
# 9                                       55.865911
#
#    Estimate; Total: - $200,000 or more  \
# 0                                 21.0
# 1                                 21.0
# 2                                  3.0
# 3                                  2.0
# 4                                  0.0
# 5                                 49.0
# 6                                  0.0
# 7                                 31.0
# 8                                  0.0
# 9                                108.0
#
#    Margin of Error; Total: - $200,000 or more
# 0                                   21.000000
# 1                                   24.000000
# 2                                   16.248077
# 3                                   15.000000
# 4                                   10.000000
# 5                                   53.310412
# 6                                   10.000000
# 7                                   36.249138
# 8                                   20.000000
# 9                                   46.925473
#
# [10 rows x 36 columns]

# %%
## estimate total
#people of $200,000+
#find percentage p/t*100
#find top 10 counties
percentage = []
counties = []

for county in range(0,household_income.index.size): #go through whole data set
    p = household_income.iloc[county,34]/household_income.iloc[county,2]
    p_round = (p.round(5))
    #print(household_income.iloc[county,0] +" "+ str(p))
    #put results in dictionary
    #results[household_income.iloc[county,0]] = str(p_round)
    percentage.append(str(p_round))
    counties.append(household_income.iloc[county,0])

results = {'County' : counties, 'Percentage': percentage}
wealth = pd.DataFrame.from_dict(results)
wealth.head(10)
# Out:
#               County Percentage
# 0   Allegheny Center    0.02414
# 1     Allegheny West    0.14384
# 2          Allentown    0.00281
# 3          Arlington    0.00285
# 4  Arlington Heights        0.0
# 5         Banksville    0.02518
# 6  Bedford Dwellings        0.0
# 7          Beechview    0.00869
# 8        Beltzhoover        0.0
# 9         Bloomfield    0.02363

# %%
wealth.sort_values(by=['Percentage'], ascending = False).tail(35)
# Out:
#                   County Percentage
# 60             Overbrook    0.00251
# 40        Homewood North    0.00248
# 71           South Shore        0.0
# 87              West End        0.0
# 88          West Oakland        0.0
# 67             Ridgemont        0.0
# 74         Spring Garden        0.0
# 78             St. Clair        0.0
# 69              Sheraden        0.0
# 45         Lincoln Place        0.0
# 58     Northview Heights        0.0
# 29               Elliott        0.0
# 4      Arlington Heights        0.0
# 6      Bedford Dwellings        0.0
# 8            Beltzhoover        0.0
# 10                 Bluff        0.0
# 11               Bon Air        0.0
# 14  California-Kirkbride        0.0
# 19       Central Oakland        0.0
# 20        Chartiers City        0.0
# 21               Chateau        0.0
# 26         East Carnegie        0.0
# 30                Esplen        0.0
# 57           North Shore        0.0
# 32              Fineview        0.0
# 33            Friendship        0.0
# 35            Glen Hazel        0.0
# 37                  Hays        0.0
# 41        Homewood South        0.0
# 42         Homewood West        0.0
# 43             Knoxville        0.0
# 49    Marshall-Shadeland        0.0
# 50           Middle Hill        0.0
# 55         New Homestead        0.0
# 90               Windgap        0.0

# %% [markdown]
# Based on this table, the last 33 counties on this list have absolutely no people making a salary of more than $200,000. By this logic, we have narrowed down the safest counties to 33 possible places.
